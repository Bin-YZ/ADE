# %% [markdown]
# # Data Extraction
#
# ## **In-Diffusion (Through-Diffusion)** Case
#
# Data is extracted from 3 different Excel sheets:
#
# ### **Sheet "Cusb"** (Upstream Reservoir Concentration)
# - `Time` - Time in days
# - `Cusb` (mol/m³) - Upstream reservoir concentration
# - `U(Cusb)` (mol/m³) - Uncertainty of Cusb
# - `Vhigh` (mL) - Upstream reservoir volume
#
# ### **Sheet "Jdsb"** (Downstream Flux)
# - `Time` - Time in days
# - `JL` (mol·s⁻¹·m⁻²) - Downstream flux
# - `U(JL)` (mol·s⁻¹·m⁻²) - Uncertainty of JL
# - `Vlow` (mL) - Downstream reservoir volume
#
# ### **Sheet "Makk"** (Solution Exchange Times)
# - `Time` - Downstream reservoir solution exchange time points
#
# **Data extraction settings**: `header=0, skiprows=[1]`
# - Row 0 (first row) contains column names
# - Row 1 (second row) is skipped (typically contains units)
# - Data extraction starts from row 2 (third row)
#
# ---
#
# ## **Out-Diffusion** Case
#
# Data is extracted from a single sheet:
#
# ### **Upstream Side (High)**
# - `time_hi` - Upstream side time in days
# - `Flux_Hi` (mol·s⁻¹·m⁻²) - Upstream side flux
# - `uFlux_Hi` (mol·s⁻¹·m⁻²) - Upstream side flux uncertainty
# - `C_high` (mol/m³) - Upstream side initial concentration
#
# ### **Downstream Side (Low)**
# - `time_lo` - Downstream side time in days
# - `Flux_Lo` (mol·s⁻¹·m⁻²) - Downstream side flux
# - `Uflux_Lo` (mol·s⁻¹·m⁻²) - Downstream side flux uncertainty
#
# **Data extraction settings**: `header=0, skiprows=[1]`
# - Row 0 (first row) contains column names
# - Row 1 (second row) is skipped (typically contains units)
# - Data extraction starts from row 2 (third row)
#
# ---
#
# ## **Important Notes**
#
# ⚠️ **The GUI program code is highly sensitive to variable names.** Therefore, the column names and units in the imported data **must remain exactly consistent** with those specified in the code. Any deviation in naming (e.g., capitalization, spacing, or spelling) will cause the data loading to fail.
#
# 📋 **Data Structure Requirements**:
# - **Row 1**: Column names (used as headers)
# - **Row 2**: Units or descriptions (automatically skipped by the code)
# - **Row 3 onwards**: Actual numerical data
#
# **Note**: All time data is originally in days in the Excel files, but the code automatically converts it to seconds (× 86400).
